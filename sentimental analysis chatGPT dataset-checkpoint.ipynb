# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
from textblob import TextBlob
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
from wordcloud import wordcloud
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix,ConfusionMatrixDisplay
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-43-b7c01668c104> in <module>()
#      15 from sklearn.model_selection import train_test_split
#      16 from sklearn.linear_model import LogisticRegression
# ---> 17 from sklearn.metrics import accuracy_score, classification_report,confusion_matrix,ConfusionMatrixDisplay
#
# ImportError: cannot import name ConfusionMatrixDisplay

# %%
df1= pd.read_csv(r"C:\Users\Lenovo\Downloads\chatgpt1.csv")

# %%
df1.head(10)
# Out:
#                     Datetime             Tweet Id  \
# 0  2023-01-22 13:44:34+00:00  1617156270871699456
# 1  2023-01-22 13:44:39+00:00  1617156291046133761
# 2  2023-01-22 13:44:44+00:00  1617156308926349312
# 3  2023-01-22 13:44:49+00:00  1617156332297256961
# 4  2023-01-22 13:44:52+00:00  1617156345064570880
# 5  2023-01-22 13:45:00+00:00  1617156376983207937
# 6  2023-01-22 13:45:03+00:00  1617156389217894400
# 7  2023-01-22 13:45:04+00:00  1617156393898745858
# 8  2023-01-22 13:45:06+00:00  1617156404137295878
# 9  2023-01-22 13:45:07+00:00  1617156405869379585
#
#                                                 Text         Username  \
# 0  ChatGPTで遊ぶの忘れてた！！\n書類作るコード書いてみてほしいのと、\nどこまで思考整...      mochico0123
# 1  @AlexandrovnaIng Prohibition of ChatGPT has be...  Caput_LupinumSG
# 2  Schaut Euch an, was @fobizz @DianaKnodel alles...            ciffi
# 3  Bow down to chatGPT 🫡..... https://t.co/ENTSz...    Vishwasrisiri
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50001 entries, 0 to 50000
# Data columns (total 20 columns):
# Datetime          50001 non-null object
# Tweet Id          50001 non-null int64
# Text              50001 non-null object
# Username          50001 non-null object
# Permalink         50001 non-null object
# User              50001 non-null object
# Outlinks          19942 non-null object
# CountLinks        19942 non-null object
# ReplyCount        50001 non-null int64
# RetweetCount      50001 non-null int64
# LikeCount         50001 non-null int64
# QuoteCount        50001 non-null int64
# ConversationId    50001 non-null int64
# Language          50001 non-null object
# Source            50001 non-null object
# Media             9502 non-null object
# QuotedTweet       3563 non-null object
# MentionedUsers    17169 non-null object
# hashtag           50001 non-null object
# hastag_counts     50001 non-null int64
# dtypes: int64(7), object(13)
# ...

# %%
df1.columns
# Out:
# Index([u'Datetime', u'Tweet Id', u'Text', u'Username', u'Permalink', u'User',
#        u'Outlinks', u'CountLinks', u'ReplyCount', u'RetweetCount',
#        u'LikeCount', u'QuoteCount', u'ConversationId', u'Language', u'Source',
#        u'Media', u'QuotedTweet', u'MentionedUsers', u'hashtag',
#        u'hastag_counts'],
#       dtype='object')

# %%
text_df = df1.drop([u'Datetime', u'Tweet Id', u'Username', u'Permalink', u'User',
       u'Outlinks', u'CountLinks', u'ReplyCount', u'RetweetCount',
       u'LikeCount', u'QuoteCount', u'ConversationId', u'Language', u'Source',
       u'Media', u'QuotedTweet', u'MentionedUsers', u'hashtag',
       u'hastag_counts'],axis=1)
text_df.head()
# Out:
#                                                 Text
# 0  ChatGPTで遊ぶの忘れてた！！\n書類作るコード書いてみてほしいのと、\nどこまで思考整...
# 1  @AlexandrovnaIng Prohibition of ChatGPT has be...
# 2  Schaut Euch an, was @fobizz @DianaKnodel alles...
# 3  Bow down to chatGPT 🫡..... https://t.co/ENTSz...
# 4  Profilinde vatan, Türkiye falan yazan bireyler...

# %%
print(text_df['Text'].iloc[1])
print(text_df['Text'].iloc[2])
print(text_df['Text'].iloc[3])
print(text_df['Text'].iloc[4])
print(text_df['Text'].iloc[5])
print(text_df['Text'].iloc[6])
# Out:
# @AlexandrovnaIng Prohibition of ChatGPT has been added to the honor code of my daughter’s school
# Schaut Euch an, was @fobizz @DianaKnodel alles ⬇️ auf die Piste bringt, um Euch mitzunehmen.
#
# Morgen startet @reg_schulz - und am Di um 12 besprechen wir #ChatGPT als kritische FreundInnen im Live-Briefing mit SPD-Vorsitzender @EskenSaskia &amp; Diana
# https://t.co/DsoeVJrPBp https://t.co/HflTruResk https://t.co/7tYCx6Srp8
# Bow down to chatGPT 🫡..... https://t.co/ENTSzi2AQ9
# Profilinde vatan, Türkiye falan yazan bireylerin ilk koruduğu şey ülkenin dini falan. Asla şaşmaz bu. Chatgpt yaz bunu bi kenara 😂
# ChatGPT’nin bilinmeyen arka planı: Ucuz iş gücü
#
# Çeviri: Evrim Şaşmaz
#
# https://t.co/daAyOpRLiM
# ChatGPT runs 10K Nvidia training GPUs with potential for thousands more https://t.co/Uhq62t0Uw4

# %%
text_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50001 entries, 0 to 50000
# Data columns (total 1 columns):
# Text    50001 non-null object
# dtypes: object(1)
# memory usage: 390.7+ KB

# %%
def data_processing(text):
    text = text.lower()
    text = re.sub(r"https\S+|www\S+https\S+", '',text,flags=re.MULTILINE)
    text = re.sub(r'\@w+|\#','',text)
    text = re.sub(r'[^\w\s]','',text)
    text_tokens = word_tokenize(text)
    filtered_text = [w for w in text_tokens if not w in stop_words]
    return " ".join(filtered_text)

# %%
text_df.Text = text_df['Text'].apply(data_processing)

# %%
text_df = text_df.drop_duplicates('Text')

# %%
stemmer = PorterStemmer()
def stemming(data):
    text = [stemmer.stem(word) for word in data]
    return data

# %%
text_df['Text'] = text_df['Text'].apply(lambda x: stemming(x))

# %%
text_df.head()
# Out:
#                                                 Text
# 0                                            chatgpt
# 1  alexandrovnaing prohibition chatgpt added hono...
# 2  schaut euch fobizz dianaknodel alles auf die p...
# 3                                        bow chatgpt
# 4  profilinde vatan trkiye falan yazan bireylerin...

# %%
print(text_df['Text'].iloc[1])
print(text_df['Text'].iloc[2])
print(text_df['Text'].iloc[3])
print(text_df['Text'].iloc[4])
print(text_df['Text'].iloc[5])
print(text_df['Text'].iloc[6])
# Out:
# alexandrovnaing prohibition chatgpt added honor code daughters school
# schaut euch fobizz dianaknodel alles auf die piste bringt um euch mitzunehmen morgen startet reg_schulz und di um 12 besprechen wir chatgpt als kritische freundinnen im livebriefing mit spdvorsitzender eskensaskia amp diana
# bow chatgpt
# profilinde vatan trkiye falan yazan bireylerin ilk koruduu ey lkenin dini falan asla amaz bu chatgpt yaz bunu bi kenara
# chatgptnin bilinmeyen arka plan ucuz gc eviri evrim amaz
# chatgpt runs 10k nvidia training gpus potential thousands

# %%
text_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42183 entries, 0 to 50000
# Data columns (total 1 columns):
# Text    42183 non-null object
# dtypes: object(1)
# memory usage: 659.1+ KB

# %%
def polarity(text):
    return TextBlob(text).sentiment.polarity

# %%
text_df['polarity'] = text_df['Text'].apply(polarity)

# %%
text_df.head(10)
# Out:
#                                                 Text  polarity
# 0                                            chatgpt  0.000000
# 1  alexandrovnaing prohibition chatgpt added hono...  0.000000
# 2  schaut euch fobizz dianaknodel alles auf die p...  0.000000
# 3                                        bow chatgpt  0.000000
# 4  profilinde vatan trkiye falan yazan bireylerin...  0.000000
# 5  chatgptnin bilinmeyen arka plan ucuz gc eviri ...  0.000000
# 6  chatgpt runs 10k nvidia training gpus potentia...  0.000000
# 7  swengdad repetitive work every job lots small ... -0.083333
# 8  created fictional jewelry brand using chatgpt ...  0.000000
# 9  look similar irobot company install mini fridg...  0.300000

# %%
def sentiment(label):
    if label<0:
        return "Negative"
    elif label ==0:
        return "Neutral"
    elif label>0:
        return "Positive"

# %%
text_df['sentiment'] = text_df['polarity'].apply(sentiment)

# %%
text_df.head()
# Out:
#                                                 Text  polarity sentiment
# 0                                            chatgpt       0.0   Neutral
# 1  alexandrovnaing prohibition chatgpt added hono...       0.0   Neutral
# 2  schaut euch fobizz dianaknodel alles auf die p...       0.0   Neutral
# 3                                        bow chatgpt       0.0   Neutral
# 4  profilinde vatan trkiye falan yazan bireylerin...       0.0   Neutral

# %%
fig = plt.figure(figsize=(5,5))
sns.countplot(x='sentiment',data = text_df)

# %%
fig = plt.figure(figsize=(7,7))
colors = ("yellowgreen", "gold","red")
wp = {'linewidth':2, 'edgecolor':"black"}
tags = text_df['sentiment'].value_counts()
explode = (0.1,0.1,0.1)
tags.plot(kind='pie', autopct='%1.1f%%',shadow=True,colors = colors,
         startangle=90,wedgeprops =wp,explode = explode, label='')
plt.title('Distribution of sentiments')
# Out:
# Text(0.5,1,'Distribution of sentiments')

# %%
pos_tweets = text_df[text_df.sentiment == 'Positive']
pos_tweets = pos_tweets.sort_values([])
